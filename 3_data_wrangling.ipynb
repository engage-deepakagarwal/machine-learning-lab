# %% [markdown]
# Data wrangling, sometimes referred to as data munging, is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics. The goal of data wrangling is to assure quality and useful data.

# %%
import pandas as pd

# %%
df_phone_prices = pd.read_csv('data/phoneprices.csv')
df_phone_prices
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
len(df_phone_prices)
# Out:
# 2000

# %%
df_phone_prices.head() # first 5 rows
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df_phone_prices.head(10) # first 10 rows
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
df_phone_prices.tail() # last 5 rows
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df_phone_prices.tail(10) # last 10 rows
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1990           1617     1          2.4         0   8       1          36
# 1991           1882     0          2.0         0  11       1          44
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1994            858     0          2.2         0   1       0          50
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1990    0.8         85        1  ...        743      1426   296     5     3
# ...

# %%
df_phone_prices[['battery_power', 'blue', 'clock_speed']]
# Out:
#       battery_power  blue  clock_speed
# 0               842     0          2.2
# 1              1021     1          0.5
# 2               563     1          0.5
# 3               615     1          2.5
# 4              1821     1          1.2
# ...             ...   ...          ...
# 1995            794     1          0.5
# 1996           1965     1          2.6
# 1997           1911     0          0.9
# 1998           1512     0          0.9
# 1999            510     1          2.0
#
# [2000 rows x 3 columns]

# %% [markdown]
# Difference between `.loc` and `.iloc`

# %%
from IPython.display import display, Image
display(Image('images/loc-vs-iloc.png'))

# %%
df_phone_prices.iloc[0:,[0, 1, 2]] # Similar to above. For indexes use iloc
# Out:
#       battery_power  blue  clock_speed
# 0               842     0          2.2
# 1              1021     1          0.5
# 2               563     1          0.5
# 3               615     1          2.5
# 4              1821     1          1.2
# ...             ...   ...          ...
# 1995            794     1          0.5
# 1996           1965     1          2.6
# 1997           1911     0          0.9
# 1998           1512     0          0.9
# 1999            510     1          2.0
#
# [2000 rows x 3 columns]

# %%
df_phone_prices[df_phone_prices['price_range'] == 1] # Price_range == 1 is considered cheap
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 12             1815     0          2.8         0   2       0          33
# 18             1131     1          0.5         1  11       0          49
# ...             ...   ...          ...       ...  ..     ...         ...
# 1981           1454     0          2.6         0   8       0           6
# 1984            797     0          2.2         1   0       0          37
# 1986           1139     1          0.9         1   6       1          58
# 1988           1547     1          2.9         0   2       0          57
# 1989            586     0          2.8         0   2       0          15
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df_phone_prices[df_phone_prices["ram"] >= 2000]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 6              1821     0          1.7         0   4       1          10
# ...             ...   ...          ...       ...  ..     ...         ...
# 1993           1467     1          0.5         0   0       0          18
# 1994            858     0          2.2         0   1       0          50
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
# Change the text entries of column price_range to cheap where the value is 1
# df_phone_prices.loc[df_phone_prices['price_range'] == 1, 'price_range'] = 'cheap' # loc with column names
df_phone_prices.iloc[df_phone_prices['price_range'] == 1, 20] = 'cheap' # iloc with column index

df_phone_prices
# Out:
# C:\Users\deepak.agarwal\AppData\Local\Temp\ipykernel_46356\2716823125.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'cheap' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_phone_prices.iloc[df_phone_prices['price_range'] == 1, 20] = 'cheap' # iloc with column index
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# ...

# %%
df_phone_prices.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
df_correlated_data = df_phone_prices.select_dtypes(include='number').corr()

# %%
# Show only the rows where the correlation is greater than 0.5
df_correlated_data[df_correlated_data > 0.5]
# Out:
#                battery_power  blue  clock_speed  dual_sim        fc    four_g  \
# battery_power            1.0   NaN          NaN       NaN       NaN       NaN
# blue                     NaN   1.0          NaN       NaN       NaN       NaN
# clock_speed              NaN   NaN          1.0       NaN       NaN       NaN
# dual_sim                 NaN   NaN          NaN       1.0       NaN       NaN
# fc                       NaN   NaN          NaN       NaN  1.000000       NaN
# four_g                   NaN   NaN          NaN       NaN       NaN  1.000000
# int_memory               NaN   NaN          NaN       NaN       NaN       NaN
# m_dep                    NaN   NaN          NaN       NaN       NaN       NaN
# mobile_wt                NaN   NaN          NaN       NaN       NaN       NaN
# n_cores                  NaN   NaN          NaN       NaN       NaN       NaN
# pc                       NaN   NaN          NaN       NaN  0.644595       NaN
# ...
